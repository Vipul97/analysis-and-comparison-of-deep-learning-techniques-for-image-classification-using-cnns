# %%
# !pip install git+https://github.com/yfw/starter-code
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/yfw/starter-code
#   Cloning https://github.com/yfw/starter-code to /tmp/pip-req-build-ku5jwji1
#   Running command git clone --filter=blob:none --quiet https://github.com/yfw/starter-code /tmp/pip-req-build-ku5jwji1
#   Resolved https://github.com/yfw/starter-code to commit 9a6269738ba0094d0bd09aea4cc21747b965c6d1
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pydrive in /usr/local/lib/python3.9/dist-packages (from Colab-Utils==0.1.dev0) (1.3.1)
# Requirement already satisfied: PyYAML>=3.0 in /usr/local/lib/python3.9/dist-packages (from pydrive->Colab-Utils==0.1.dev0) (6.0)
# Requirement already satisfied: google-api-python-client>=1.2 in /usr/local/lib/python3.9/dist-packages (from pydrive->Colab-Utils==0.1.dev0) (2.70.0)
# Requirement already satisfied: oauth2client>=4.0.0 in /usr/local/lib/python3.9/dist-packages (from pydrive->Colab-Utils==0.1.dev0) (4.1.3)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.9/dist-packages (from google-api-python-client>=1.2->pydrive->Colab-Utils==0.1.dev0) (4.1.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /usr/local/lib/python3.9/dist-packages (from google-api-python-client>=1.2->pydrive->Colab-Utils==0.1.dev0) (2.11.0)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.19.0 in /usr/local/lib/python3.9/dist-packages (from google-api-python-client>=1.2->pydrive->Colab-Utils==0.1.dev0) (2.17.1)
# Requirement already satisfied: google-auth-httplib2>=0.1.0 in /usr/local/lib/python3.9/dist-packages (from google-api-python-client>=1.2->pydrive->Colab-Utils==0.1.dev0) (0.1.0)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /usr/local/lib/python3.9/dist-packages (from google-api-python-client>=1.2->pydrive->Colab-Utils==0.1.dev0) (0.21.0)
# Requirement already satisfied: pyasn1>=0.1.7 in /usr/local/lib/python3.9/dist-packages (from oauth2client>=4.0.0->pydrive->Colab-Utils==0.1.dev0) (0.4.8)
# Requirement already satisfied: six>=1.6.1 in /usr/local/lib/python3.9/dist-packages (from oauth2client>=4.0.0->pydrive->Colab-Utils==0.1.dev0) (1.16.0)
# Requirement already satisfied: rsa>=3.1.4 in /usr/local/lib/python3.9/dist-packages (from oauth2client>=4.0.0->pydrive->Colab-Utils==0.1.dev0) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /usr/local/lib/python3.9/dist-packages (from oauth2client>=4.0.0->pydrive->Colab-Utils==0.1.dev0) (0.2.8)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in /usr/local/lib/python3.9/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.2->pydrive->Colab-Utils==0.1.dev0) (3.20.3)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /usr/local/lib/python3.9/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.2->pydrive->Colab-Utils==0.1.dev0) (1.59.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.9/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.2->pydrive->Colab-Utils==0.1.dev0) (2.27.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from google-auth<3.0.0dev,>=1.19.0->google-api-python-client>=1.2->pydrive->Colab-Utils==0.1.dev0) (5.3.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.9/dist-packages (from httplib2<1dev,>=0.15.0->google-api-python-client>=1.2->pydrive->Colab-Utils==0.1.dev0) (3.0.9)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.2->pydrive->Colab-Utils==0.1.dev0) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.2->pydrive->Colab-Utils==0.1.dev0) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.2->pydrive->Colab-Utils==0.1.dev0) (3.4)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client>=1.2->pydrive->Colab-Utils==0.1.dev0) (2.0.12)

# %%
import coutils
from coutils import fix_random_seed

from collections import OrderedDict
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader
from torch.utils.data import sampler

import torchvision.datasets as dset
import torchvision.transforms as T

# for plotting
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %%
NUM_TRAIN = 49000

# The torchvision.transforms package provides tools for preprocessing data
# and for performing data augmentation; here we set up a transform to
# preprocess the data by subtracting the mean RGB value and dividing by the
# standard deviation of each RGB value; we've hardcoded the mean and std.
transform = T.Compose([
                T.ToTensor(),
                T.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
            ])

# We set up a Dataset object for each split (train / val / test); Datasets load
# training examples one at a time, so we wrap each Dataset in a DataLoader which
# iterates through the Dataset and forms minibatches. We divide the CIFAR-10
# training set into train and val sets by passing a Sampler object to the
# DataLoader telling how it should sample from the underlying Dataset.
cifar10_train = dset.CIFAR10('./datasets', train=True, download=True,
                             transform=transform)
loader_train = DataLoader(cifar10_train, batch_size=64, 
                          sampler=sampler.SubsetRandomSampler(range(NUM_TRAIN)))

cifar10_val = dset.CIFAR10('./datasets', train=True, download=True,
                           transform=transform)
loader_val = DataLoader(cifar10_val, batch_size=64, 
                        sampler=sampler.SubsetRandomSampler(range(NUM_TRAIN, 50000)))

cifar10_test = dset.CIFAR10('./datasets', train=False, download=True, 
                            transform=transform)
loader_test = DataLoader(cifar10_test, batch_size=64)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %%
dtype = torch.float
ltype = torch.long

if torch.cuda.is_available():
  device = torch.device('cuda:0')
else:
  device = torch.device('cpu')

# Constant to control how frequently we print train loss
print_every = 100

print('using device:', device)
# Out:
# using device: cuda:0

# %%
def flatten(x, start_dim=1, end_dim=-1):
  return x.flatten(start_dim=start_dim, end_dim=end_dim)

# %%
class Flatten(nn.Module):
  def forward(self, x):
    return flatten(x)

# %%
def check_accuracy_part34(loader, model):
  if loader.dataset.train:
    print('Checking accuracy on validation set')
  else:
    print('Checking accuracy on test set')   
  num_correct = 0
  num_samples = 0
  model.eval()  # set model to evaluation mode
  with torch.no_grad():
    for x, y in loader:
      x = x.to(device=device, dtype=dtype)  # move to device, e.g. GPU
      y = y.to(device=device, dtype=ltype)
      scores = model(x)
      _, preds = scores.max(1)
      num_correct += (preds == y).sum()
      num_samples += preds.size(0)
    acc = float(num_correct) / num_samples
    print('Got %d / %d correct (%.2f)' % (num_correct, num_samples, 100 * acc))
  return acc

# %%
def train_part(model, optimizer, epochs=1):
    """
    Train a model on CIFAR-10 using the PyTorch Module API.
    
    Inputs:
    - model: A PyTorch Module giving the model to train.
    - optimizer: An Optimizer object we will use to train the model
    - epochs: (Optional) A Python integer giving the number of epochs to train for
    
    Returns: Accuracy, also prints model accuracies during training.
    """
    model = model.to(device=device)  # move the model parameters to CPU/GPU
    acc = 0
    for e in range(epochs):
        for t, (x, y) in enumerate(loader_train):
            model.train()  # put model to training mode
            x = x.to(device=device, dtype=dtype)  # move to device, e.g. GPU
            y = y.to(device=device, dtype=torch.long)

            scores = model(x)
            loss = F.cross_entropy(scores, y)

            # Zero out all of the gradients for the variables which the optimizer
            # will update.
            optimizer.zero_grad()

            # This is the backwards pass: compute the gradient of the loss with
            # respect to each  parameter of the model.
            loss.backward()

            # Actually update the parameters of the model using the gradients
            # computed by the backwards pass.
            optimizer.step()

            if t % print_every == 0:
                print('Iteration %d, loss = %.4f' % (t, loss.item()))
                acc = check_accuracy_part34(loader_val, model)
                print()
    return acc

# %% [markdown]
# Here we train a model using SGD without Nesterov momentum.

# %%
fix_random_seed(0)

C, H, W = 3, 32, 32
num_classes = 10

channel_1 = 16
channel_2 = 32
channel_3 = 64

kernel_size_1 = 3
kernel_size_2 = 3
kernel_size_3 = 6

pad_size_1 = 2
pad_size_2 = 1
pad_size_3 = 1

learning_rate = 1e-2
momentum = 0.5
weight_decay = 1e-4

# my own added parameters
pool_kernel_size = 2

# calculate shape between layers
H_after_conv1 = int(H + 2*pad_size_1 - 1*(kernel_size_1-1) - 1 + 1)
W_after_conv1 = int(W + 2*pad_size_1 - 1*(kernel_size_1-1) - 1 + 1)
H_after_pool1 = int((H_after_conv1 + 2*0 - 1*(pool_kernel_size-1) - 1) / pool_kernel_size + 1)
W_after_pool1 = int((W_after_conv1 + 2*0 - 1*(pool_kernel_size-1) - 1) / pool_kernel_size + 1)

H_after_conv2 = int(H_after_pool1 + 2*pad_size_2 - 1*(kernel_size_2-1) - 1 + 1)
W_after_conv2 = int(W_after_pool1 + 2*pad_size_2 - 1*(kernel_size_2-1) - 1 + 1)
H_after_pool2 = int((H_after_conv2 + 2*0 - 1*(pool_kernel_size-1) - 1) / pool_kernel_size + 1)
W_after_pool2 = int((W_after_conv2 + 2*0 - 1*(pool_kernel_size-1) - 1) / pool_kernel_size + 1)

H_after_conv3 = int(H_after_pool2 + 2*pad_size_3 - 1*(kernel_size_3-1) - 1 + 1)
W_after_conv3 = int(W_after_pool2 + 2*pad_size_3 - 1*(kernel_size_3-1) - 1 + 1)
H_after_pool3 = int((H_after_conv3 + 2*0 - 1*(pool_kernel_size-1) - 1) / pool_kernel_size + 1)
W_after_pool3 = int((W_after_conv3 + 2*0 - 1*(pool_kernel_size-1) - 1) / pool_kernel_size + 1)

model1 = nn.Sequential(OrderedDict([
  ('conv1', nn.Conv2d(C, channel_1, (kernel_size_1,kernel_size_1), padding=pad_size_1)),
  ('batchnorm1', nn.BatchNorm2d(channel_1)),
  ('relu1', nn.ReLU()),
  #('dropout1', nn.Dropout2d()),
  ('maxpool1', nn.MaxPool2d(pool_kernel_size)),

  ('conv2', nn.Conv2d(channel_1, channel_2, (kernel_size_2,kernel_size_2), padding=pad_size_2)),
  ('batchnorm2', nn.BatchNorm2d(channel_2)),
  ('relu2', nn.ReLU()),
  #('dropout2', nn.Dropout2d()),
  ('maxpool2', nn.MaxPool2d(pool_kernel_size)),

  ('conv3', nn.Conv2d(channel_2, channel_3, (kernel_size_3,kernel_size_3), padding=pad_size_3)),
  ('batchnorm3', nn.BatchNorm2d(channel_3)),
  ('relu3', nn.ReLU()),
  #('dropout3', nn.Dropout2d()),
  ('maxpool3', nn.MaxPool2d(pool_kernel_size)),
  
  # # the ending option 1
  # ('avgpool', nn.AvgPool2d((H_after_pool3, W_after_pool3))),
  # ('flatten', Flatten()),
  # ('fc', nn.Linear(1*1*channel_3, num_classes)),
  
  # the ending option 2
  ('flatten', Flatten()),
  ('fc', nn.Linear(H_after_pool3*W_after_pool3*channel_3, num_classes)),
]))

optimizer1 = optim.SGD(model1.parameters(), lr=learning_rate, 
                      weight_decay=weight_decay,
                      momentum=0, nesterov=False)
# END OF YOUR CODE

# You should get at least 70% accuracy
train_part(model1, optimizer1, epochs=10)
# Out:
# Iteration 0, loss = 2.3975
# Checking accuracy on validation set
# Got 98 / 1000 correct (9.80)
#
# Iteration 100, loss = 1.8358
# Checking accuracy on validation set
# Got 420 / 1000 correct (42.00)
#
# Iteration 200, loss = 1.5136
# Checking accuracy on validation set
# Got 484 / 1000 correct (48.40)
#
# Iteration 300, loss = 1.2554
# Checking accuracy on validation set
# Got 506 / 1000 correct (50.60)
#
# Iteration 400, loss = 1.3212
# Checking accuracy on validation set
# Got 522 / 1000 correct (52.20)
#
# Iteration 500, loss = 1.1832
# Checking accuracy on validation set
# Got 533 / 1000 correct (53.30)
#
# Iteration 600, loss = 1.0599
# Checking accuracy on validation set
# Got 553 / 1000 correct (55.30)
#
# Iteration 700, loss = 1.4052
# Checking accuracy on validation set
# Got 568 / 1000 correct (56.80)
#
# Iteration 0, loss = 0.9499
# Checking accuracy on validation set
# Got 602 / 1000 correct (60.20)
#
# Iteration 100, loss = 1.3063
# Checking accuracy on validation set
# Got 602 / 1000 correct (60.20)
#
# Iteration 200, loss = 1.2288
# Checking accuracy on validation set
# Got 612 / 1000 correct (61.20)
#
# Iteration 300, loss = 0.9674
# Checking accuracy on validation set
# Got 619 / 1000 correct (61.90)
#
# Iteration 400, loss = 1.1854
# Checking accuracy on validation set
# Got 587 / 1000 correct (58.70)
#
# Iteration 500, loss = 1.1417
# Checking accuracy on validation set
# Got 609 / 1000 correct (60.90)
#
# Iteration 600, loss = 0.9351
# Checking accuracy on validation set
# Got 629 / 1000 correct (62.90)
#
# Iteration 700, loss = 1.0039
# Checking accuracy on validation set
# Got 608 / 1000 correct (60.80)
#
# Iteration 0, loss = 0.9621
# Checking accuracy on validation set
# Got 651 / 1000 correct (65.10)
#
# Iteration 100, loss = 1.0070
# Checking accuracy on validation set
# Got 641 / 1000 correct (64.10)
#
# Iteration 200, loss = 0.8804
# Checking accuracy on validation set
# Got 659 / 1000 correct (65.90)
#
# Iteration 300, loss = 0.9269
# Checking accuracy on validation set
# Got 662 / 1000 correct (66.20)
#
# Iteration 400, loss = 0.8230
# Checking accuracy on validation set
# Got 654 / 1000 correct (65.40)
#
# Iteration 500, loss = 0.9031
# Checking accuracy on validation set
# Got 633 / 1000 correct (63.30)
#
# Iteration 600, loss = 0.8076
# Checking accuracy on validation set
# Got 657 / 1000 correct (65.70)
#
# Iteration 700, loss = 0.9968
# Checking accuracy on validation set
# Got 655 / 1000 correct (65.50)
#
# Iteration 0, loss = 0.7133
# Checking accuracy on validation set
# Got 672 / 1000 correct (67.20)
#
# Iteration 100, loss = 0.8282
# Checking accuracy on validation set
# Got 645 / 1000 correct (64.50)
#
# Iteration 200, loss = 0.7380
# Checking accuracy on validation set
# Got 675 / 1000 correct (67.50)
#
# Iteration 300, loss = 0.9025
# Checking accuracy on validation set
# Got 681 / 1000 correct (68.10)
#
# Iteration 400, loss = 0.7973
# Checking accuracy on validation set
# Got 671 / 1000 correct (67.10)
#
# Iteration 500, loss = 1.0624
# Checking accuracy on validation set
# Got 694 / 1000 correct (69.40)
#
# Iteration 600, loss = 1.0019
# Checking accuracy on validation set
# Got 662 / 1000 correct (66.20)
#
# Iteration 700, loss = 0.6945
# Checking accuracy on validation set
# Got 693 / 1000 correct (69.30)
#
# Iteration 0, loss = 1.0458
# Checking accuracy on validation set
# Got 707 / 1000 correct (70.70)
#
# Iteration 100, loss = 0.9602
# Checking accuracy on validation set
# Got 692 / 1000 correct (69.20)
#
# Iteration 200, loss = 0.9362
# Checking accuracy on validation set
# Got 688 / 1000 correct (68.80)
#
# Iteration 300, loss = 0.7247
# Checking accuracy on validation set
# Got 703 / 1000 correct (70.30)
#
# Iteration 400, loss = 0.9231
# Checking accuracy on validation set
# Got 683 / 1000 correct (68.30)
#
# Iteration 500, loss = 0.6839
# Checking accuracy on validation set
# Got 671 / 1000 correct (67.10)
#
# Iteration 600, loss = 0.6824
# Checking accuracy on validation set
# Got 683 / 1000 correct (68.30)
#
# Iteration 700, loss = 0.6797
# Checking accuracy on validation set
# Got 695 / 1000 correct (69.50)
#
# Iteration 0, loss = 0.7493
# Checking accuracy on validation set
# Got 680 / 1000 correct (68.00)
#
# Iteration 100, loss = 0.6625
# Checking accuracy on validation set
# Got 685 / 1000 correct (68.50)
#
# Iteration 200, loss = 0.5684
# Checking accuracy on validation set
# Got 697 / 1000 correct (69.70)
#
# Iteration 300, loss = 0.7919
# Checking accuracy on validation set
# Got 704 / 1000 correct (70.40)
#
# Iteration 400, loss = 0.7385
# Checking accuracy on validation set
# Got 685 / 1000 correct (68.50)
#
# Iteration 500, loss = 0.6448
# Checking accuracy on validation set
# Got 707 / 1000 correct (70.70)
#
# Iteration 600, loss = 0.9169
# Checking accuracy on validation set
# Got 700 / 1000 correct (70.00)
#
# Iteration 700, loss = 0.6768
# Checking accuracy on validation set
# Got 707 / 1000 correct (70.70)
#
# Iteration 0, loss = 0.9081
# Checking accuracy on validation set
# Got 724 / 1000 correct (72.40)
#
# Iteration 100, loss = 0.5614
# Checking accuracy on validation set
# Got 709 / 1000 correct (70.90)
#
# Iteration 200, loss = 0.6861
# Checking accuracy on validation set
# Got 706 / 1000 correct (70.60)
#
# Iteration 300, loss = 0.5208
# Checking accuracy on validation set
# Got 714 / 1000 correct (71.40)
#
# Iteration 400, loss = 0.5772
# Checking accuracy on validation set
# Got 713 / 1000 correct (71.30)
#
# Iteration 500, loss = 0.7617
# Checking accuracy on validation set
# Got 719 / 1000 correct (71.90)
#
# Iteration 600, loss = 0.7055
# Checking accuracy on validation set
# Got 699 / 1000 correct (69.90)
#
# Iteration 700, loss = 0.7309
# Checking accuracy on validation set
# Got 721 / 1000 correct (72.10)
#
# Iteration 0, loss = 0.6673
# Checking accuracy on validation set
# Got 739 / 1000 correct (73.90)
#
# Iteration 100, loss = 0.6064
# Checking accuracy on validation set
# Got 719 / 1000 correct (71.90)
#
# Iteration 200, loss = 0.7876
# Checking accuracy on validation set
# Got 710 / 1000 correct (71.00)
#
# Iteration 300, loss = 0.5284
# Checking accuracy on validation set
# Got 717 / 1000 correct (71.70)
#
# Iteration 400, loss = 0.5722
# Checking accuracy on validation set
# Got 713 / 1000 correct (71.30)
#
# Iteration 500, loss = 0.5982
# Checking accuracy on validation set
# Got 721 / 1000 correct (72.10)
#
# Iteration 600, loss = 0.5688
# Checking accuracy on validation set
# Got 706 / 1000 correct (70.60)
#
# Iteration 700, loss = 0.6586
# Checking accuracy on validation set
# Got 717 / 1000 correct (71.70)
#
# Iteration 0, loss = 0.5548
# Checking accuracy on validation set
# Got 705 / 1000 correct (70.50)
#
# Iteration 100, loss = 0.6409
# Checking accuracy on validation set
# Got 716 / 1000 correct (71.60)
#
# Iteration 200, loss = 0.6076
# Checking accuracy on validation set
# Got 713 / 1000 correct (71.30)
#
# Iteration 300, loss = 0.6966
# Checking accuracy on validation set
# Got 735 / 1000 correct (73.50)
#
# Iteration 400, loss = 0.6040
# Checking accuracy on validation set
# Got 717 / 1000 correct (71.70)
#
# Iteration 500, loss = 0.5654
# Checking accuracy on validation set
# Got 705 / 1000 correct (70.50)
#
# Iteration 600, loss = 0.4888
# Checking accuracy on validation set
# Got 733 / 1000 correct (73.30)
#
# Iteration 700, loss = 0.7392
# Checking accuracy on validation set
# Got 725 / 1000 correct (72.50)
#
# Iteration 0, loss = 0.4781
# Checking accuracy on validation set
# Got 708 / 1000 correct (70.80)
#
# Iteration 100, loss = 0.5374
# Checking accuracy on validation set
# Got 723 / 1000 correct (72.30)
#
# Iteration 200, loss = 0.4459
# Checking accuracy on validation set
# Got 715 / 1000 correct (71.50)
#
# Iteration 300, loss = 0.5258
# Checking accuracy on validation set
# Got 734 / 1000 correct (73.40)
#
# Iteration 400, loss = 0.8015
# Checking accuracy on validation set
# Got 706 / 1000 correct (70.60)
#
# Iteration 500, loss = 0.4629
# Checking accuracy on validation set
# Got 710 / 1000 correct (71.00)
#
# Iteration 600, loss = 0.5903
# Checking accuracy on validation set
# Got 731 / 1000 correct (73.10)
#
# Iteration 700, loss = 0.3720
# Checking accuracy on validation set
# Got 742 / 1000 correct (74.20)
# 0.742

# %% [markdown]
# Next we train a model with Nesterov momentum.

# %%
fix_random_seed(0)

C, H, W = 3, 32, 32
num_classes = 10

channel_1 = 16
channel_2 = 32
channel_3 = 64

kernel_size_1 = 3
kernel_size_2 = 3
kernel_size_3 = 6

pad_size_1 = 2
pad_size_2 = 1
pad_size_3 = 1

learning_rate = 1e-2
momentum = 0.5
weight_decay = 1e-4

# my own added parameters
pool_kernel_size = 2

# calculate shape between layers
H_after_conv1 = int(H + 2*pad_size_1 - 1*(kernel_size_1-1) - 1 + 1)
W_after_conv1 = int(W + 2*pad_size_1 - 1*(kernel_size_1-1) - 1 + 1)
H_after_pool1 = int((H_after_conv1 + 2*0 - 1*(pool_kernel_size-1) - 1) / pool_kernel_size + 1)
W_after_pool1 = int((W_after_conv1 + 2*0 - 1*(pool_kernel_size-1) - 1) / pool_kernel_size + 1)

H_after_conv2 = int(H_after_pool1 + 2*pad_size_2 - 1*(kernel_size_2-1) - 1 + 1)
W_after_conv2 = int(W_after_pool1 + 2*pad_size_2 - 1*(kernel_size_2-1) - 1 + 1)
H_after_pool2 = int((H_after_conv2 + 2*0 - 1*(pool_kernel_size-1) - 1) / pool_kernel_size + 1)
W_after_pool2 = int((W_after_conv2 + 2*0 - 1*(pool_kernel_size-1) - 1) / pool_kernel_size + 1)

H_after_conv3 = int(H_after_pool2 + 2*pad_size_3 - 1*(kernel_size_3-1) - 1 + 1)
W_after_conv3 = int(W_after_pool2 + 2*pad_size_3 - 1*(kernel_size_3-1) - 1 + 1)
H_after_pool3 = int((H_after_conv3 + 2*0 - 1*(pool_kernel_size-1) - 1) / pool_kernel_size + 1)
W_after_pool3 = int((W_after_conv3 + 2*0 - 1*(pool_kernel_size-1) - 1) / pool_kernel_size + 1)

model2 = nn.Sequential(OrderedDict([
  ('conv1', nn.Conv2d(C, channel_1, (kernel_size_1,kernel_size_1), padding=pad_size_1)),
  ('batchnorm1', nn.BatchNorm2d(channel_1)),
  ('relu1', nn.ReLU()),
  #('dropout1', nn.Dropout2d()),
  ('maxpool1', nn.MaxPool2d(pool_kernel_size)),

  ('conv2', nn.Conv2d(channel_1, channel_2, (kernel_size_2,kernel_size_2), padding=pad_size_2)),
  ('batchnorm2', nn.BatchNorm2d(channel_2)),
  ('relu2', nn.ReLU()),
  #('dropout2', nn.Dropout2d()),
  ('maxpool2', nn.MaxPool2d(pool_kernel_size)),

  ('conv3', nn.Conv2d(channel_2, channel_3, (kernel_size_3,kernel_size_3), padding=pad_size_3)),
  ('batchnorm3', nn.BatchNorm2d(channel_3)),
  ('relu3', nn.ReLU()),
  #('dropout3', nn.Dropout2d()),
  ('maxpool3', nn.MaxPool2d(pool_kernel_size)),
  
  # # the ending option 1
  # ('avgpool', nn.AvgPool2d((H_after_pool3, W_after_pool3))),
  # ('flatten', Flatten()),
  # ('fc', nn.Linear(1*1*channel_3, num_classes)),
  
  # the ending option 2
  ('flatten', Flatten()),
  ('fc', nn.Linear(H_after_pool3*W_after_pool3*channel_3, num_classes)),
]))

optimizer2 = optim.SGD(model2.parameters(), lr=learning_rate, 
                      weight_decay=weight_decay,
                      momentum=momentum, nesterov=True)
# END OF YOUR CODE

# You should get at least 70% accuracy
train_part(model2, optimizer2, epochs=10)
# Out:
# Iteration 0, loss = 2.3975
# Checking accuracy on validation set
# Got 104 / 1000 correct (10.40)
#
# Iteration 100, loss = 1.7141
# Checking accuracy on validation set
# Got 490 / 1000 correct (49.00)
#
# Iteration 200, loss = 1.3997
# Checking accuracy on validation set
# Got 540 / 1000 correct (54.00)
#
# Iteration 300, loss = 1.2386
# Checking accuracy on validation set
# Got 523 / 1000 correct (52.30)
#
# Iteration 400, loss = 1.2174
# Checking accuracy on validation set
# Got 540 / 1000 correct (54.00)
#
# Iteration 500, loss = 1.0554
# Checking accuracy on validation set
# Got 553 / 1000 correct (55.30)
#
# Iteration 600, loss = 0.9361
# Checking accuracy on validation set
# Got 569 / 1000 correct (56.90)
#
# Iteration 700, loss = 1.2736
# Checking accuracy on validation set
# Got 594 / 1000 correct (59.40)
#
# Iteration 0, loss = 0.8884
# Checking accuracy on validation set
# Got 618 / 1000 correct (61.80)
#
# Iteration 100, loss = 1.1403
# Checking accuracy on validation set
# Got 609 / 1000 correct (60.90)
#
# Iteration 200, loss = 1.1661
# Checking accuracy on validation set
# Got 649 / 1000 correct (64.90)
#
# Iteration 300, loss = 0.8241
# Checking accuracy on validation set
# Got 642 / 1000 correct (64.20)
#
# Iteration 400, loss = 1.0058
# Checking accuracy on validation set
# Got 607 / 1000 correct (60.70)
#
# Iteration 500, loss = 1.0276
# Checking accuracy on validation set
# Got 633 / 1000 correct (63.30)
#
# Iteration 600, loss = 0.7754
# Checking accuracy on validation set
# Got 659 / 1000 correct (65.90)
#
# Iteration 700, loss = 0.9643
# Checking accuracy on validation set
# Got 650 / 1000 correct (65.00)
#
# Iteration 0, loss = 0.9049
# Checking accuracy on validation set
# Got 681 / 1000 correct (68.10)
#
# Iteration 100, loss = 0.9740
# Checking accuracy on validation set
# Got 679 / 1000 correct (67.90)
#
# Iteration 200, loss = 0.7345
# Checking accuracy on validation set
# Got 684 / 1000 correct (68.40)
#
# Iteration 300, loss = 0.7984
# Checking accuracy on validation set
# Got 662 / 1000 correct (66.20)
#
# Iteration 400, loss = 0.7055
# Checking accuracy on validation set
# Got 686 / 1000 correct (68.60)
#
# Iteration 500, loss = 0.8810
# Checking accuracy on validation set
# Got 671 / 1000 correct (67.10)
#
# Iteration 600, loss = 0.7914
# Checking accuracy on validation set
# Got 692 / 1000 correct (69.20)
#
# Iteration 700, loss = 0.8408
# Checking accuracy on validation set
# Got 671 / 1000 correct (67.10)
#
# Iteration 0, loss = 0.6822
# Checking accuracy on validation set
# Got 704 / 1000 correct (70.40)
#
# Iteration 100, loss = 0.7806
# Checking accuracy on validation set
# Got 675 / 1000 correct (67.50)
#
# Iteration 200, loss = 0.6408
# Checking accuracy on validation set
# Got 694 / 1000 correct (69.40)
#
# Iteration 300, loss = 0.8979
# Checking accuracy on validation set
# Got 701 / 1000 correct (70.10)
#
# Iteration 400, loss = 0.7363
# Checking accuracy on validation set
# Got 687 / 1000 correct (68.70)
#
# Iteration 500, loss = 0.9776
# Checking accuracy on validation set
# Got 729 / 1000 correct (72.90)
#
# Iteration 600, loss = 0.9498
# Checking accuracy on validation set
# Got 704 / 1000 correct (70.40)
#
# Iteration 700, loss = 0.6510
# Checking accuracy on validation set
# Got 723 / 1000 correct (72.30)
#
# Iteration 0, loss = 1.0461
# Checking accuracy on validation set
# Got 714 / 1000 correct (71.40)
#
# Iteration 100, loss = 0.9171
# Checking accuracy on validation set
# Got 699 / 1000 correct (69.90)
#
# Iteration 200, loss = 0.8642
# Checking accuracy on validation set
# Got 710 / 1000 correct (71.00)
#
# Iteration 300, loss = 0.7304
# Checking accuracy on validation set
# Got 725 / 1000 correct (72.50)
#
# Iteration 400, loss = 0.8082
# Checking accuracy on validation set
# Got 714 / 1000 correct (71.40)
#
# Iteration 500, loss = 0.6491
# Checking accuracy on validation set
# Got 701 / 1000 correct (70.10)
#
# Iteration 600, loss = 0.6747
# Checking accuracy on validation set
# Got 703 / 1000 correct (70.30)
#
# Iteration 700, loss = 0.5922
# Checking accuracy on validation set
# Got 705 / 1000 correct (70.50)
#
# Iteration 0, loss = 0.6654
# Checking accuracy on validation set
# Got 703 / 1000 correct (70.30)
#
# Iteration 100, loss = 0.4848
# Checking accuracy on validation set
# Got 722 / 1000 correct (72.20)
#
# Iteration 200, loss = 0.4901
# Checking accuracy on validation set
# Got 716 / 1000 correct (71.60)
#
# Iteration 300, loss = 0.6820
# Checking accuracy on validation set
# Got 722 / 1000 correct (72.20)
#
# Iteration 400, loss = 0.6772
# Checking accuracy on validation set
# Got 723 / 1000 correct (72.30)
#
# Iteration 500, loss = 0.5458
# Checking accuracy on validation set
# Got 724 / 1000 correct (72.40)
#
# Iteration 600, loss = 0.8527
# Checking accuracy on validation set
# Got 715 / 1000 correct (71.50)
#
# Iteration 700, loss = 0.5642
# Checking accuracy on validation set
# Got 743 / 1000 correct (74.30)
#
# Iteration 0, loss = 0.7881
# Checking accuracy on validation set
# Got 728 / 1000 correct (72.80)
#
# Iteration 100, loss = 0.5405
# Checking accuracy on validation set
# Got 728 / 1000 correct (72.80)
#
# Iteration 200, loss = 0.6585
# Checking accuracy on validation set
# Got 707 / 1000 correct (70.70)
#
# Iteration 300, loss = 0.5030
# Checking accuracy on validation set
# Got 724 / 1000 correct (72.40)
#
# Iteration 400, loss = 0.5651
# Checking accuracy on validation set
# Got 735 / 1000 correct (73.50)
#
# Iteration 500, loss = 0.6715
# Checking accuracy on validation set
# Got 727 / 1000 correct (72.70)
#
# Iteration 600, loss = 0.5993
# Checking accuracy on validation set
# Got 717 / 1000 correct (71.70)
#
# Iteration 700, loss = 0.6751
# Checking accuracy on validation set
# Got 735 / 1000 correct (73.50)
#
# Iteration 0, loss = 0.4440
# Checking accuracy on validation set
# Got 752 / 1000 correct (75.20)
#
# Iteration 100, loss = 0.4984
# Checking accuracy on validation set
# Got 720 / 1000 correct (72.00)
#
# Iteration 200, loss = 0.6529
# Checking accuracy on validation set
# Got 739 / 1000 correct (73.90)
#
# Iteration 300, loss = 0.4248
# Checking accuracy on validation set
# Got 747 / 1000 correct (74.70)
#
# Iteration 400, loss = 0.5301
# Checking accuracy on validation set
# Got 737 / 1000 correct (73.70)
#
# Iteration 500, loss = 0.5522
# Checking accuracy on validation set
# Got 739 / 1000 correct (73.90)
#
# Iteration 600, loss = 0.5225
# Checking accuracy on validation set
# Got 718 / 1000 correct (71.80)
#
# Iteration 700, loss = 0.5714
# Checking accuracy on validation set
# Got 718 / 1000 correct (71.80)
#
# Iteration 0, loss = 0.3510
# Checking accuracy on validation set
# Got 730 / 1000 correct (73.00)
#
# Iteration 100, loss = 0.3944
# Checking accuracy on validation set
# Got 720 / 1000 correct (72.00)
#
# Iteration 200, loss = 0.4911
# Checking accuracy on validation set
# Got 739 / 1000 correct (73.90)
#
# Iteration 300, loss = 0.6403
# Checking accuracy on validation set
# Got 743 / 1000 correct (74.30)
#
# Iteration 400, loss = 0.5183
# Checking accuracy on validation set
# Got 726 / 1000 correct (72.60)
#
# Iteration 500, loss = 0.5335
# Checking accuracy on validation set
# Got 752 / 1000 correct (75.20)
#
# Iteration 600, loss = 0.4118
# Checking accuracy on validation set
# Got 742 / 1000 correct (74.20)
#
# Iteration 700, loss = 0.5664
# Checking accuracy on validation set
# Got 750 / 1000 correct (75.00)
#
# Iteration 0, loss = 0.2938
# Checking accuracy on validation set
# Got 753 / 1000 correct (75.30)
#
# Iteration 100, loss = 0.3932
# Checking accuracy on validation set
# Got 747 / 1000 correct (74.70)
#
# Iteration 200, loss = 0.3377
# Checking accuracy on validation set
# Got 737 / 1000 correct (73.70)
#
# Iteration 300, loss = 0.3513
# Checking accuracy on validation set
# Got 718 / 1000 correct (71.80)
#
# Iteration 400, loss = 0.6204
# Checking accuracy on validation set
# Got 748 / 1000 correct (74.80)
#
# Iteration 500, loss = 0.4509
# Checking accuracy on validation set
# Got 739 / 1000 correct (73.90)
#
# Iteration 600, loss = 0.5828
# Checking accuracy on validation set
# Got 715 / 1000 correct (71.50)
#
# Iteration 700, loss = 0.2701
# Checking accuracy on validation set
# Got 775 / 1000 correct (77.50)
# 0.775

# %% [markdown]
# Model with adagrad optimizer:

# %%
fix_random_seed(0)

C, H, W = 3, 32, 32
num_classes = 10

channel_1 = 16
channel_2 = 32
channel_3 = 64

kernel_size_1 = 3
kernel_size_2 = 3
kernel_size_3 = 6

pad_size_1 = 2
pad_size_2 = 1
pad_size_3 = 1

learning_rate = 1e-2
momentum = 0.5
weight_decay = 1e-4

# my own added parameters
pool_kernel_size = 2

# calculate shape between layers
H_after_conv1 = int(H + 2*pad_size_1 - 1*(kernel_size_1-1) - 1 + 1)
W_after_conv1 = int(W + 2*pad_size_1 - 1*(kernel_size_1-1) - 1 + 1)
H_after_pool1 = int((H_after_conv1 + 2*0 - 1*(pool_kernel_size-1) - 1) / pool_kernel_size + 1)
W_after_pool1 = int((W_after_conv1 + 2*0 - 1*(pool_kernel_size-1) - 1) / pool_kernel_size + 1)

H_after_conv2 = int(H_after_pool1 + 2*pad_size_2 - 1*(kernel_size_2-1) - 1 + 1)
W_after_conv2 = int(W_after_pool1 + 2*pad_size_2 - 1*(kernel_size_2-1) - 1 + 1)
H_after_pool2 = int((H_after_conv2 + 2*0 - 1*(pool_kernel_size-1) - 1) / pool_kernel_size + 1)
W_after_pool2 = int((W_after_conv2 + 2*0 - 1*(pool_kernel_size-1) - 1) / pool_kernel_size + 1)

H_after_conv3 = int(H_after_pool2 + 2*pad_size_3 - 1*(kernel_size_3-1) - 1 + 1)
W_after_conv3 = int(W_after_pool2 + 2*pad_size_3 - 1*(kernel_size_3-1) - 1 + 1)
H_after_pool3 = int((H_after_conv3 + 2*0 - 1*(pool_kernel_size-1) - 1) / pool_kernel_size + 1)
W_after_pool3 = int((W_after_conv3 + 2*0 - 1*(pool_kernel_size-1) - 1) / pool_kernel_size + 1)

model3 = nn.Sequential(OrderedDict([
  ('conv1', nn.Conv2d(C, channel_1, (kernel_size_1,kernel_size_1), padding=pad_size_1)),
  ('batchnorm1', nn.BatchNorm2d(channel_1)),
  ('relu1', nn.ReLU()),
  #('dropout1', nn.Dropout2d()),
  ('maxpool1', nn.MaxPool2d(pool_kernel_size)),

  ('conv2', nn.Conv2d(channel_1, channel_2, (kernel_size_2,kernel_size_2), padding=pad_size_2)),
  ('batchnorm2', nn.BatchNorm2d(channel_2)),
  ('relu2', nn.ReLU()),
  #('dropout2', nn.Dropout2d()),
  ('maxpool2', nn.MaxPool2d(pool_kernel_size)),

  ('conv3', nn.Conv2d(channel_2, channel_3, (kernel_size_3,kernel_size_3), padding=pad_size_3)),
  ('batchnorm3', nn.BatchNorm2d(channel_3)),
  ('relu3', nn.ReLU()),
  #('dropout3', nn.Dropout2d()),
  ('maxpool3', nn.MaxPool2d(pool_kernel_size)),
  
  # # the ending option 1
  # ('avgpool', nn.AvgPool2d((H_after_pool3, W_after_pool3))),
  # ('flatten', Flatten()),
  # ('fc', nn.Linear(1*1*channel_3, num_classes)),
  
  # the ending option 2
  ('flatten', Flatten()),
  ('fc', nn.Linear(H_after_pool3*W_after_pool3*channel_3, num_classes)),
])).cuda()

optimizer3 = optim.Adagrad(model3.parameters(), lr=learning_rate, 
                      weight_decay=weight_decay)
# END OF YOUR CODE

# You should get at least 70% accuracy
train_part(model3, optimizer3, epochs=10)
# Out:
# Iteration 0, loss = 2.3975
# Checking accuracy on validation set
# Got 113 / 1000 correct (11.30)
#
# Iteration 100, loss = 1.5706
# Checking accuracy on validation set
# Got 517 / 1000 correct (51.70)
#
# Iteration 200, loss = 1.2788
# Checking accuracy on validation set
# Got 585 / 1000 correct (58.50)
#
# Iteration 300, loss = 0.9900
# Checking accuracy on validation set
# Got 610 / 1000 correct (61.00)
#
# Iteration 400, loss = 1.0535
# Checking accuracy on validation set
# Got 619 / 1000 correct (61.90)
#
# Iteration 500, loss = 0.9415
# Checking accuracy on validation set
# Got 604 / 1000 correct (60.40)
#
# Iteration 600, loss = 0.8224
# Checking accuracy on validation set
# Got 613 / 1000 correct (61.30)
#
# Iteration 700, loss = 1.1606
# Checking accuracy on validation set
# Got 640 / 1000 correct (64.00)
#
# Iteration 0, loss = 0.8358
# Checking accuracy on validation set
# Got 654 / 1000 correct (65.40)
#
# Iteration 100, loss = 1.0648
# Checking accuracy on validation set
# Got 664 / 1000 correct (66.40)
#
# Iteration 200, loss = 0.9610
# Checking accuracy on validation set
# Got 675 / 1000 correct (67.50)
#
# Iteration 300, loss = 0.7575
# Checking accuracy on validation set
# Got 675 / 1000 correct (67.50)
#
# Iteration 400, loss = 0.8182
# Checking accuracy on validation set
# Got 671 / 1000 correct (67.10)
#
# Iteration 500, loss = 0.8923
# Checking accuracy on validation set
# Got 683 / 1000 correct (68.30)
#
# Iteration 600, loss = 0.7916
# Checking accuracy on validation set
# Got 684 / 1000 correct (68.40)
#
# Iteration 700, loss = 0.9378
# Checking accuracy on validation set
# Got 680 / 1000 correct (68.00)
#
# Iteration 0, loss = 0.7966
# Checking accuracy on validation set
# Got 692 / 1000 correct (69.20)
#
# Iteration 100, loss = 0.9171
# Checking accuracy on validation set
# Got 686 / 1000 correct (68.60)
#
# Iteration 200, loss = 0.7367
# Checking accuracy on validation set
# Got 707 / 1000 correct (70.70)
#
# Iteration 300, loss = 0.8378
# Checking accuracy on validation set
# Got 686 / 1000 correct (68.60)
#
# Iteration 400, loss = 0.7211
# Checking accuracy on validation set
# Got 699 / 1000 correct (69.90)
#
# Iteration 500, loss = 0.7560
# Checking accuracy on validation set
# Got 695 / 1000 correct (69.50)
#
# Iteration 600, loss = 0.7167
# Checking accuracy on validation set
# Got 713 / 1000 correct (71.30)
#
# Iteration 700, loss = 0.8290
# Checking accuracy on validation set
# Got 708 / 1000 correct (70.80)
#
# Iteration 0, loss = 0.5901
# Checking accuracy on validation set
# Got 710 / 1000 correct (71.00)
#
# Iteration 100, loss = 0.5827
# Checking accuracy on validation set
# Got 706 / 1000 correct (70.60)
#
# Iteration 200, loss = 0.6319
# Checking accuracy on validation set
# Got 707 / 1000 correct (70.70)
#
# Iteration 300, loss = 0.9419
# Checking accuracy on validation set
# Got 715 / 1000 correct (71.50)
#
# Iteration 400, loss = 0.6768
# Checking accuracy on validation set
# Got 708 / 1000 correct (70.80)
#
# Iteration 500, loss = 0.8656
# Checking accuracy on validation set
# Got 721 / 1000 correct (72.10)
#
# Iteration 600, loss = 0.7616
# Checking accuracy on validation set
# Got 728 / 1000 correct (72.80)
#
# Iteration 700, loss = 0.6463
# Checking accuracy on validation set
# Got 726 / 1000 correct (72.60)
#
# Iteration 0, loss = 0.8986
# Checking accuracy on validation set
# Got 720 / 1000 correct (72.00)
#
# Iteration 100, loss = 0.8362
# Checking accuracy on validation set
# Got 720 / 1000 correct (72.00)
#
# Iteration 200, loss = 0.8821
# Checking accuracy on validation set
# Got 725 / 1000 correct (72.50)
#
# Iteration 300, loss = 0.6758
# Checking accuracy on validation set
# Got 719 / 1000 correct (71.90)
#
# Iteration 400, loss = 0.7616
# Checking accuracy on validation set
# Got 727 / 1000 correct (72.70)
#
# Iteration 500, loss = 0.6040
# Checking accuracy on validation set
# Got 718 / 1000 correct (71.80)
#
# Iteration 600, loss = 0.5755
# Checking accuracy on validation set
# Got 712 / 1000 correct (71.20)
#
# Iteration 700, loss = 0.6437
# Checking accuracy on validation set
# Got 723 / 1000 correct (72.30)
#
# Iteration 0, loss = 0.6324
# Checking accuracy on validation set
# Got 720 / 1000 correct (72.00)
#
# Iteration 100, loss = 0.5230
# Checking accuracy on validation set
# Got 722 / 1000 correct (72.20)
#
# Iteration 200, loss = 0.5952
# Checking accuracy on validation set
# Got 717 / 1000 correct (71.70)
#
# Iteration 300, loss = 0.6888
# Checking accuracy on validation set
# Got 722 / 1000 correct (72.20)
#
# Iteration 400, loss = 0.6104
# Checking accuracy on validation set
# Got 715 / 1000 correct (71.50)
#
# Iteration 500, loss = 0.4655
# Checking accuracy on validation set
# Got 730 / 1000 correct (73.00)
#
# Iteration 600, loss = 0.8281
# Checking accuracy on validation set
# Got 730 / 1000 correct (73.00)
#
# Iteration 700, loss = 0.6125
# Checking accuracy on validation set
# Got 728 / 1000 correct (72.80)
#
# Iteration 0, loss = 0.8202
# Checking accuracy on validation set
# Got 723 / 1000 correct (72.30)
#
# Iteration 100, loss = 0.5925
# Checking accuracy on validation set
# Got 713 / 1000 correct (71.30)
#
# Iteration 200, loss = 0.6681
# Checking accuracy on validation set
# Got 721 / 1000 correct (72.10)
#
# Iteration 300, loss = 0.4670
# Checking accuracy on validation set
# Got 722 / 1000 correct (72.20)
#
# Iteration 400, loss = 0.4279
# Checking accuracy on validation set
# Got 732 / 1000 correct (73.20)
#
# Iteration 500, loss = 0.7588
# Checking accuracy on validation set
# Got 722 / 1000 correct (72.20)
#
# Iteration 600, loss = 0.6767
# Checking accuracy on validation set
# Got 729 / 1000 correct (72.90)
#
# Iteration 700, loss = 0.5555
# Checking accuracy on validation set
# Got 726 / 1000 correct (72.60)
#
# Iteration 0, loss = 0.8132
# Checking accuracy on validation set
# Got 743 / 1000 correct (74.30)
#
# Iteration 100, loss = 0.5099
# Checking accuracy on validation set
# Got 740 / 1000 correct (74.00)
#
# Iteration 200, loss = 0.7390
# Checking accuracy on validation set
# Got 725 / 1000 correct (72.50)
#
# Iteration 300, loss = 0.4134
# Checking accuracy on validation set
# Got 733 / 1000 correct (73.30)
#
# Iteration 400, loss = 0.6610
# Checking accuracy on validation set
# Got 727 / 1000 correct (72.70)
#
# Iteration 500, loss = 0.4762
# Checking accuracy on validation set
# Got 719 / 1000 correct (71.90)
#
# Iteration 600, loss = 0.4320
# Checking accuracy on validation set
# Got 726 / 1000 correct (72.60)
#
# Iteration 700, loss = 0.6055
# Checking accuracy on validation set
# Got 740 / 1000 correct (74.00)
#
# Iteration 0, loss = 0.4822
# Checking accuracy on validation set
# Got 732 / 1000 correct (73.20)
#
# Iteration 100, loss = 0.5683
# Checking accuracy on validation set
# Got 727 / 1000 correct (72.70)
#
# Iteration 200, loss = 0.5204
# Checking accuracy on validation set
# Got 732 / 1000 correct (73.20)
#
# Iteration 300, loss = 0.6602
# Checking accuracy on validation set
# Got 727 / 1000 correct (72.70)
#
# Iteration 400, loss = 0.6235
# Checking accuracy on validation set
# Got 733 / 1000 correct (73.30)
#
# Iteration 500, loss = 0.4523
# Checking accuracy on validation set
# Got 732 / 1000 correct (73.20)
#
# Iteration 600, loss = 0.4200
# Checking accuracy on validation set
# Got 736 / 1000 correct (73.60)
#
# Iteration 700, loss = 0.6591
# Checking accuracy on validation set
# Got 738 / 1000 correct (73.80)
#
# Iteration 0, loss = 0.4469
# Checking accuracy on validation set
# Got 745 / 1000 correct (74.50)
#
# Iteration 100, loss = 0.5063
# Checking accuracy on validation set
# Got 734 / 1000 correct (73.40)
#
# Iteration 200, loss = 0.4308
# Checking accuracy on validation set
# Got 748 / 1000 correct (74.80)
#
# Iteration 300, loss = 0.4652
# Checking accuracy on validation set
# Got 731 / 1000 correct (73.10)
#
# Iteration 400, loss = 0.6967
# Checking accuracy on validation set
# Got 734 / 1000 correct (73.40)
#
# Iteration 500, loss = 0.4526
# Checking accuracy on validation set
# Got 732 / 1000 correct (73.20)
#
# Iteration 600, loss = 0.6020
# Checking accuracy on validation set
# Got 736 / 1000 correct (73.60)
#
# Iteration 700, loss = 0.3333
# Checking accuracy on validation set
# Got 731 / 1000 correct (73.10)
# 0.731

# %% [markdown]
# Model with RMSProp optimizer:

# %%
fix_random_seed(0)

C, H, W = 3, 32, 32
num_classes = 10

channel_1 = 16
channel_2 = 32
channel_3 = 64

kernel_size_1 = 3
kernel_size_2 = 3
kernel_size_3 = 6

pad_size_1 = 2
pad_size_2 = 1
pad_size_3 = 1

learning_rate = 1e-2
momentum = 0.5
weight_decay = 1e-4

# my own added parameters
pool_kernel_size = 2

# calculate shape between layers
H_after_conv1 = int(H + 2*pad_size_1 - 1*(kernel_size_1-1) - 1 + 1)
W_after_conv1 = int(W + 2*pad_size_1 - 1*(kernel_size_1-1) - 1 + 1)
H_after_pool1 = int((H_after_conv1 + 2*0 - 1*(pool_kernel_size-1) - 1) / pool_kernel_size + 1)
W_after_pool1 = int((W_after_conv1 + 2*0 - 1*(pool_kernel_size-1) - 1) / pool_kernel_size + 1)

H_after_conv2 = int(H_after_pool1 + 2*pad_size_2 - 1*(kernel_size_2-1) - 1 + 1)
W_after_conv2 = int(W_after_pool1 + 2*pad_size_2 - 1*(kernel_size_2-1) - 1 + 1)
H_after_pool2 = int((H_after_conv2 + 2*0 - 1*(pool_kernel_size-1) - 1) / pool_kernel_size + 1)
W_after_pool2 = int((W_after_conv2 + 2*0 - 1*(pool_kernel_size-1) - 1) / pool_kernel_size + 1)

H_after_conv3 = int(H_after_pool2 + 2*pad_size_3 - 1*(kernel_size_3-1) - 1 + 1)
W_after_conv3 = int(W_after_pool2 + 2*pad_size_3 - 1*(kernel_size_3-1) - 1 + 1)
H_after_pool3 = int((H_after_conv3 + 2*0 - 1*(pool_kernel_size-1) - 1) / pool_kernel_size + 1)
W_after_pool3 = int((W_after_conv3 + 2*0 - 1*(pool_kernel_size-1) - 1) / pool_kernel_size + 1)

model4 = nn.Sequential(OrderedDict([
  ('conv1', nn.Conv2d(C, channel_1, (kernel_size_1,kernel_size_1), padding=pad_size_1)),
  ('batchnorm1', nn.BatchNorm2d(channel_1)),
  ('relu1', nn.ReLU()),
  #('dropout1', nn.Dropout2d()),
  ('maxpool1', nn.MaxPool2d(pool_kernel_size)),

  ('conv2', nn.Conv2d(channel_1, channel_2, (kernel_size_2,kernel_size_2), padding=pad_size_2)),
  ('batchnorm2', nn.BatchNorm2d(channel_2)),
  ('relu2', nn.ReLU()),
  #('dropout2', nn.Dropout2d()),
  ('maxpool2', nn.MaxPool2d(pool_kernel_size)),

  ('conv3', nn.Conv2d(channel_2, channel_3, (kernel_size_3,kernel_size_3), padding=pad_size_3)),
  ('batchnorm3', nn.BatchNorm2d(channel_3)),
  ('relu3', nn.ReLU()),
  #('dropout3', nn.Dropout2d()),
  ('maxpool3', nn.MaxPool2d(pool_kernel_size)),
  
  # # the ending option 1
  # ('avgpool', nn.AvgPool2d((H_after_pool3, W_after_pool3))),
  # ('flatten', Flatten()),
  # ('fc', nn.Linear(1*1*channel_3, num_classes)),
  
  # the ending option 2
  ('flatten', Flatten()),
  ('fc', nn.Linear(H_after_pool3*W_after_pool3*channel_3, num_classes)),
]))

optimizer4 = optim.RMSprop(model4.parameters(), lr=learning_rate, 
                      weight_decay=weight_decay, momentum=momentum)
# END OF YOUR CODE

# You should get at least 70% accuracy
train_part(model4, optimizer4, epochs=10)
# Out:
# Iteration 0, loss = 2.3975
# Checking accuracy on validation set
# Got 106 / 1000 correct (10.60)
#
# Iteration 100, loss = 1.8706
# Checking accuracy on validation set
# Got 401 / 1000 correct (40.10)
#
# Iteration 200, loss = 1.5201
# Checking accuracy on validation set
# Got 469 / 1000 correct (46.90)
#
# Iteration 300, loss = 1.3443
# Checking accuracy on validation set
# Got 466 / 1000 correct (46.60)
#
# Iteration 400, loss = 1.4646
# Checking accuracy on validation set
# Got 530 / 1000 correct (53.00)
#
# Iteration 500, loss = 1.2190
# Checking accuracy on validation set
# Got 522 / 1000 correct (52.20)
#
# Iteration 600, loss = 1.0290
# Checking accuracy on validation set
# Got 494 / 1000 correct (49.40)
#
# Iteration 700, loss = 1.4220
# Checking accuracy on validation set
# Got 571 / 1000 correct (57.10)
#
# Iteration 0, loss = 1.0794
# Checking accuracy on validation set
# Got 582 / 1000 correct (58.20)
#
# Iteration 100, loss = 1.3459
# Checking accuracy on validation set
# Got 586 / 1000 correct (58.60)
#
# Iteration 200, loss = 1.2448
# Checking accuracy on validation set
# Got 574 / 1000 correct (57.40)
#
# Iteration 300, loss = 0.8817
# Checking accuracy on validation set
# Got 588 / 1000 correct (58.80)
#
# Iteration 400, loss = 1.0969
# Checking accuracy on validation set
# Got 520 / 1000 correct (52.00)
#
# Iteration 500, loss = 1.0722
# Checking accuracy on validation set
# Got 595 / 1000 correct (59.50)
#
# Iteration 600, loss = 1.0077
# Checking accuracy on validation set
# Got 605 / 1000 correct (60.50)
#
# Iteration 700, loss = 1.0565
# Checking accuracy on validation set
# Got 451 / 1000 correct (45.10)
#
# Iteration 0, loss = 1.1150
# Checking accuracy on validation set
# Got 592 / 1000 correct (59.20)
#
# Iteration 100, loss = 1.2318
# Checking accuracy on validation set
# Got 600 / 1000 correct (60.00)
#
# Iteration 200, loss = 1.2263
# Checking accuracy on validation set
# Got 621 / 1000 correct (62.10)
#
# Iteration 300, loss = 0.9428
# Checking accuracy on validation set
# Got 638 / 1000 correct (63.80)
#
# Iteration 400, loss = 1.0208
# Checking accuracy on validation set
# Got 622 / 1000 correct (62.20)
#
# Iteration 500, loss = 0.9785
# Checking accuracy on validation set
# Got 629 / 1000 correct (62.90)
#
# Iteration 600, loss = 0.9351
# Checking accuracy on validation set
# Got 605 / 1000 correct (60.50)
#
# Iteration 700, loss = 1.0870
# Checking accuracy on validation set
# Got 660 / 1000 correct (66.00)
#
# Iteration 0, loss = 0.7825
# Checking accuracy on validation set
# Got 550 / 1000 correct (55.00)
#
# Iteration 100, loss = 0.9171
# Checking accuracy on validation set
# Got 661 / 1000 correct (66.10)
#
# Iteration 200, loss = 0.8567
# Checking accuracy on validation set
# Got 655 / 1000 correct (65.50)
#
# Iteration 300, loss = 1.2855
# Checking accuracy on validation set
# Got 615 / 1000 correct (61.50)
#
# Iteration 400, loss = 0.9430
# Checking accuracy on validation set
# Got 613 / 1000 correct (61.30)
#
# Iteration 500, loss = 1.2138
# Checking accuracy on validation set
# Got 625 / 1000 correct (62.50)
#
# Iteration 600, loss = 0.9195
# Checking accuracy on validation set
# Got 638 / 1000 correct (63.80)
#
# Iteration 700, loss = 0.8800
# Checking accuracy on validation set
# Got 614 / 1000 correct (61.40)
#
# Iteration 0, loss = 1.2910
# Checking accuracy on validation set
# Got 565 / 1000 correct (56.50)
#
# Iteration 100, loss = 1.0534
# Checking accuracy on validation set
# Got 615 / 1000 correct (61.50)
#
# Iteration 200, loss = 1.3250
# Checking accuracy on validation set
# Got 663 / 1000 correct (66.30)
#
# Iteration 300, loss = 0.9736
# Checking accuracy on validation set
# Got 652 / 1000 correct (65.20)
#
# Iteration 400, loss = 1.0731
# Checking accuracy on validation set
# Got 604 / 1000 correct (60.40)
#
# Iteration 500, loss = 0.8489
# Checking accuracy on validation set
# Got 630 / 1000 correct (63.00)
#
# Iteration 600, loss = 0.8713
# Checking accuracy on validation set
# Got 652 / 1000 correct (65.20)
#
# Iteration 700, loss = 0.7670
# Checking accuracy on validation set
# Got 518 / 1000 correct (51.80)
#
# Iteration 0, loss = 0.9179
# Checking accuracy on validation set
# Got 594 / 1000 correct (59.40)
#
# Iteration 100, loss = 0.8717
# Checking accuracy on validation set
# Got 596 / 1000 correct (59.60)
#
# Iteration 200, loss = 0.8282
# Checking accuracy on validation set
# Got 641 / 1000 correct (64.10)
#
# Iteration 300, loss = 1.0445
# Checking accuracy on validation set
# Got 676 / 1000 correct (67.60)
#
# Iteration 400, loss = 0.9834
# Checking accuracy on validation set
# Got 650 / 1000 correct (65.00)
#
# Iteration 500, loss = 0.7740
# Checking accuracy on validation set
# Got 666 / 1000 correct (66.60)
#
# Iteration 600, loss = 0.8454
# Checking accuracy on validation set
# Got 667 / 1000 correct (66.70)
#
# Iteration 700, loss = 0.9982
# Checking accuracy on validation set
# Got 651 / 1000 correct (65.10)
#
# Iteration 0, loss = 1.1156
# Checking accuracy on validation set
# Got 640 / 1000 correct (64.00)
#
# Iteration 100, loss = 0.9124
# Checking accuracy on validation set
# Got 623 / 1000 correct (62.30)
#
# Iteration 200, loss = 1.0551
# Checking accuracy on validation set
# Got 664 / 1000 correct (66.40)
#
# Iteration 300, loss = 0.7419
# Checking accuracy on validation set
# Got 672 / 1000 correct (67.20)
#
# Iteration 400, loss = 0.8245
# Checking accuracy on validation set
# Got 638 / 1000 correct (63.80)
#
# Iteration 500, loss = 0.8276
# Checking accuracy on validation set
# Got 662 / 1000 correct (66.20)
#
# Iteration 600, loss = 0.9735
# Checking accuracy on validation set
# Got 640 / 1000 correct (64.00)
#
# Iteration 700, loss = 1.2428
# Checking accuracy on validation set
# Got 643 / 1000 correct (64.30)
#
# Iteration 0, loss = 0.8995
# Checking accuracy on validation set
# Got 668 / 1000 correct (66.80)
#
# Iteration 100, loss = 0.8248
# Checking accuracy on validation set
# Got 677 / 1000 correct (67.70)
#
# Iteration 200, loss = 1.0735
# Checking accuracy on validation set
# Got 672 / 1000 correct (67.20)
#
# Iteration 300, loss = 0.8181
# Checking accuracy on validation set
# Got 640 / 1000 correct (64.00)
#
# Iteration 400, loss = 0.9281
# Checking accuracy on validation set
# Got 679 / 1000 correct (67.90)
#
# Iteration 500, loss = 1.0219
# Checking accuracy on validation set
# Got 661 / 1000 correct (66.10)
#
# Iteration 600, loss = 0.8935
# Checking accuracy on validation set
# Got 654 / 1000 correct (65.40)
#
# Iteration 700, loss = 0.8359
# Checking accuracy on validation set
# Got 638 / 1000 correct (63.80)
#
# Iteration 0, loss = 0.8012
# Checking accuracy on validation set
# Got 667 / 1000 correct (66.70)
#
# Iteration 100, loss = 0.9797
# Checking accuracy on validation set
# Got 633 / 1000 correct (63.30)
#
# Iteration 200, loss = 0.8925
# Checking accuracy on validation set
# Got 606 / 1000 correct (60.60)
#
# Iteration 300, loss = 0.9936
# Checking accuracy on validation set
# Got 686 / 1000 correct (68.60)
#
# Iteration 400, loss = 0.8394
# Checking accuracy on validation set
# Got 607 / 1000 correct (60.70)
#
# Iteration 500, loss = 0.8552
# Checking accuracy on validation set
# Got 630 / 1000 correct (63.00)
#
# Iteration 600, loss = 0.8058
# Checking accuracy on validation set
# Got 662 / 1000 correct (66.20)
#
# Iteration 700, loss = 1.0800
# Checking accuracy on validation set
# Got 657 / 1000 correct (65.70)
#
# Iteration 0, loss = 0.7690
# Checking accuracy on validation set
# Got 679 / 1000 correct (67.90)
#
# Iteration 100, loss = 0.9867
# Checking accuracy on validation set
# Got 683 / 1000 correct (68.30)
#
# Iteration 200, loss = 1.0126
# Checking accuracy on validation set
# Got 671 / 1000 correct (67.10)
#
# Iteration 300, loss = 0.8627
# Checking accuracy on validation set
# Got 632 / 1000 correct (63.20)
#
# Iteration 400, loss = 1.0164
# Checking accuracy on validation set
# Got 691 / 1000 correct (69.10)
#
# Iteration 500, loss = 0.9193
# Checking accuracy on validation set
# Got 682 / 1000 correct (68.20)
#
# Iteration 600, loss = 0.9910
# Checking accuracy on validation set
# Got 690 / 1000 correct (69.00)
#
# Iteration 700, loss = 0.7593
# Checking accuracy on validation set
# Got 666 / 1000 correct (66.60)
# 0.666

# %% [markdown]
# Model with Adam optimizer:

# %%
fix_random_seed(0)

C, H, W = 3, 32, 32
num_classes = 10

channel_1 = 16
channel_2 = 32
channel_3 = 64

kernel_size_1 = 3
kernel_size_2 = 3
kernel_size_3 = 6

pad_size_1 = 2
pad_size_2 = 1
pad_size_3 = 1

learning_rate = 1e-2
momentum = 0.5
weight_decay = 1e-4

# my own added parameters
pool_kernel_size = 2

# calculate shape between layers
H_after_conv1 = int(H + 2*pad_size_1 - 1*(kernel_size_1-1) - 1 + 1)
W_after_conv1 = int(W + 2*pad_size_1 - 1*(kernel_size_1-1) - 1 + 1)
H_after_pool1 = int((H_after_conv1 + 2*0 - 1*(pool_kernel_size-1) - 1) / pool_kernel_size + 1)
W_after_pool1 = int((W_after_conv1 + 2*0 - 1*(pool_kernel_size-1) - 1) / pool_kernel_size + 1)

H_after_conv2 = int(H_after_pool1 + 2*pad_size_2 - 1*(kernel_size_2-1) - 1 + 1)
W_after_conv2 = int(W_after_pool1 + 2*pad_size_2 - 1*(kernel_size_2-1) - 1 + 1)
H_after_pool2 = int((H_after_conv2 + 2*0 - 1*(pool_kernel_size-1) - 1) / pool_kernel_size + 1)
W_after_pool2 = int((W_after_conv2 + 2*0 - 1*(pool_kernel_size-1) - 1) / pool_kernel_size + 1)

H_after_conv3 = int(H_after_pool2 + 2*pad_size_3 - 1*(kernel_size_3-1) - 1 + 1)
W_after_conv3 = int(W_after_pool2 + 2*pad_size_3 - 1*(kernel_size_3-1) - 1 + 1)
H_after_pool3 = int((H_after_conv3 + 2*0 - 1*(pool_kernel_size-1) - 1) / pool_kernel_size + 1)
W_after_pool3 = int((W_after_conv3 + 2*0 - 1*(pool_kernel_size-1) - 1) / pool_kernel_size + 1)

model5 = nn.Sequential(OrderedDict([
  ('conv1', nn.Conv2d(C, channel_1, (kernel_size_1,kernel_size_1), padding=pad_size_1)),
  ('batchnorm1', nn.BatchNorm2d(channel_1)),
  ('relu1', nn.ReLU()),
  #('dropout1', nn.Dropout2d()),
  ('maxpool1', nn.MaxPool2d(pool_kernel_size)),

  ('conv2', nn.Conv2d(channel_1, channel_2, (kernel_size_2,kernel_size_2), padding=pad_size_2)),
  ('batchnorm2', nn.BatchNorm2d(channel_2)),
  ('relu2', nn.ReLU()),
  #('dropout2', nn.Dropout2d()),
  ('maxpool2', nn.MaxPool2d(pool_kernel_size)),

  ('conv3', nn.Conv2d(channel_2, channel_3, (kernel_size_3,kernel_size_3), padding=pad_size_3)),
  ('batchnorm3', nn.BatchNorm2d(channel_3)),
  ('relu3', nn.ReLU()),
  #('dropout3', nn.Dropout2d()),
  ('maxpool3', nn.MaxPool2d(pool_kernel_size)),
  
  # # the ending option 1
  # ('avgpool', nn.AvgPool2d((H_after_pool3, W_after_pool3))),
  # ('flatten', Flatten()),
  # ('fc', nn.Linear(1*1*channel_3, num_classes)),
  
  # the ending option 2
  ('flatten', Flatten()),
  ('fc', nn.Linear(H_after_pool3*W_after_pool3*channel_3, num_classes)),
]))

optimizer5 = optim.Adam(model5.parameters(), lr=learning_rate, 
                      weight_decay=weight_decay)
# END OF YOUR CODE

# You should get at least 70% accuracy
train_part(model5, optimizer5, epochs=10)
# Out:
# Iteration 0, loss = 2.3975
# Checking accuracy on validation set
# Got 113 / 1000 correct (11.30)
#
# Iteration 100, loss = 1.8487
# Checking accuracy on validation set
# Got 465 / 1000 correct (46.50)
#
# Iteration 200, loss = 1.4225
# Checking accuracy on validation set
# Got 522 / 1000 correct (52.20)
#
# Iteration 300, loss = 1.0528
# Checking accuracy on validation set
# Got 520 / 1000 correct (52.00)
#
# Iteration 400, loss = 1.1470
# Checking accuracy on validation set
# Got 501 / 1000 correct (50.10)
#
# Iteration 500, loss = 1.1194
# Checking accuracy on validation set
# Got 583 / 1000 correct (58.30)
#
# Iteration 600, loss = 0.8535
# Checking accuracy on validation set
# Got 588 / 1000 correct (58.80)
#
# Iteration 700, loss = 1.3584
# Checking accuracy on validation set
# Got 635 / 1000 correct (63.50)
#
# Iteration 0, loss = 0.8737
# Checking accuracy on validation set
# Got 652 / 1000 correct (65.20)
#
# Iteration 100, loss = 0.8278
# Checking accuracy on validation set
# Got 653 / 1000 correct (65.30)
#
# Iteration 200, loss = 1.0600
# Checking accuracy on validation set
# Got 670 / 1000 correct (67.00)
#
# Iteration 300, loss = 0.7276
# Checking accuracy on validation set
# Got 673 / 1000 correct (67.30)
#
# Iteration 400, loss = 0.7915
# Checking accuracy on validation set
# Got 609 / 1000 correct (60.90)
#
# Iteration 500, loss = 0.8774
# Checking accuracy on validation set
# Got 685 / 1000 correct (68.50)
#
# Iteration 600, loss = 0.8030
# Checking accuracy on validation set
# Got 662 / 1000 correct (66.20)
#
# Iteration 700, loss = 1.0877
# Checking accuracy on validation set
# Got 697 / 1000 correct (69.70)
#
# Iteration 0, loss = 0.7430
# Checking accuracy on validation set
# Got 683 / 1000 correct (68.30)
#
# Iteration 100, loss = 0.8765
# Checking accuracy on validation set
# Got 707 / 1000 correct (70.70)
#
# Iteration 200, loss = 0.8543
# Checking accuracy on validation set
# Got 672 / 1000 correct (67.20)
#
# Iteration 300, loss = 0.8629
# Checking accuracy on validation set
# Got 669 / 1000 correct (66.90)
#
# Iteration 400, loss = 0.8096
# Checking accuracy on validation set
# Got 657 / 1000 correct (65.70)
#
# Iteration 500, loss = 0.8133
# Checking accuracy on validation set
# Got 664 / 1000 correct (66.40)
#
# Iteration 600, loss = 0.7154
# Checking accuracy on validation set
# Got 699 / 1000 correct (69.90)
#
# Iteration 700, loss = 0.8052
# Checking accuracy on validation set
# Got 686 / 1000 correct (68.60)
#
# Iteration 0, loss = 0.7479
# Checking accuracy on validation set
# Got 676 / 1000 correct (67.60)
#
# Iteration 100, loss = 0.7370
# Checking accuracy on validation set
# Got 709 / 1000 correct (70.90)
#
# Iteration 200, loss = 0.5864
# Checking accuracy on validation set
# Got 719 / 1000 correct (71.90)
#
# Iteration 300, loss = 0.9390
# Checking accuracy on validation set
# Got 669 / 1000 correct (66.90)
#
# Iteration 400, loss = 0.9130
# Checking accuracy on validation set
# Got 719 / 1000 correct (71.90)
#
# Iteration 500, loss = 0.8143
# Checking accuracy on validation set
# Got 707 / 1000 correct (70.70)
#
# Iteration 600, loss = 0.9610
# Checking accuracy on validation set
# Got 716 / 1000 correct (71.60)
#
# Iteration 700, loss = 0.6893
# Checking accuracy on validation set
# Got 732 / 1000 correct (73.20)
#
# Iteration 0, loss = 0.8618
# Checking accuracy on validation set
# Got 734 / 1000 correct (73.40)
#
# Iteration 100, loss = 0.9319
# Checking accuracy on validation set
# Got 693 / 1000 correct (69.30)
#
# Iteration 200, loss = 1.0848
# Checking accuracy on validation set
# Got 724 / 1000 correct (72.40)
#
# Iteration 300, loss = 0.6941
# Checking accuracy on validation set
# Got 725 / 1000 correct (72.50)
#
# Iteration 400, loss = 0.7793
# Checking accuracy on validation set
# Got 709 / 1000 correct (70.90)
#
# Iteration 500, loss = 0.7172
# Checking accuracy on validation set
# Got 731 / 1000 correct (73.10)
#
# Iteration 600, loss = 0.6776
# Checking accuracy on validation set
# Got 698 / 1000 correct (69.80)
#
# Iteration 700, loss = 0.7500
# Checking accuracy on validation set
# Got 688 / 1000 correct (68.80)
#
# Iteration 0, loss = 0.6192
# Checking accuracy on validation set
# Got 707 / 1000 correct (70.70)
#
# Iteration 100, loss = 0.5853
# Checking accuracy on validation set
# Got 729 / 1000 correct (72.90)
#
# Iteration 200, loss = 0.5540
# Checking accuracy on validation set
# Got 709 / 1000 correct (70.90)
#
# Iteration 300, loss = 0.6314
# Checking accuracy on validation set
# Got 729 / 1000 correct (72.90)
#
# Iteration 400, loss = 0.8268
# Checking accuracy on validation set
# Got 705 / 1000 correct (70.50)
#
# Iteration 500, loss = 0.5283
# Checking accuracy on validation set
# Got 732 / 1000 correct (73.20)
#
# Iteration 600, loss = 0.8175
# Checking accuracy on validation set
# Got 696 / 1000 correct (69.60)
#
# Iteration 700, loss = 0.7174
# Checking accuracy on validation set
# Got 690 / 1000 correct (69.00)
#
# Iteration 0, loss = 0.8545
# Checking accuracy on validation set
# Got 726 / 1000 correct (72.60)
#
# Iteration 100, loss = 0.6170
# Checking accuracy on validation set
# Got 730 / 1000 correct (73.00)
#
# Iteration 200, loss = 0.8178
# Checking accuracy on validation set
# Got 713 / 1000 correct (71.30)
#
# Iteration 300, loss = 0.6606
# Checking accuracy on validation set
# Got 750 / 1000 correct (75.00)
#
# Iteration 400, loss = 0.5647
# Checking accuracy on validation set
# Got 736 / 1000 correct (73.60)
#
# Iteration 500, loss = 0.7208
# Checking accuracy on validation set
# Got 757 / 1000 correct (75.70)
#
# Iteration 600, loss = 0.7206
# Checking accuracy on validation set
# Got 711 / 1000 correct (71.10)
#
# Iteration 700, loss = 0.7922
# Checking accuracy on validation set
# Got 714 / 1000 correct (71.40)
#
# Iteration 0, loss = 0.7581
# Checking accuracy on validation set
# Got 708 / 1000 correct (70.80)
#
# Iteration 100, loss = 0.6521
# Checking accuracy on validation set
# Got 709 / 1000 correct (70.90)
#
# Iteration 200, loss = 0.8872
# Checking accuracy on validation set
# Got 740 / 1000 correct (74.00)
#
# Iteration 300, loss = 0.5373
# Checking accuracy on validation set
# Got 714 / 1000 correct (71.40)
#
# Iteration 400, loss = 0.7331
# Checking accuracy on validation set
# Got 731 / 1000 correct (73.10)
#
# Iteration 500, loss = 0.6012
# Checking accuracy on validation set
# Got 677 / 1000 correct (67.70)
#
# Iteration 600, loss = 0.7783
# Checking accuracy on validation set
# Got 742 / 1000 correct (74.20)
#
# Iteration 700, loss = 0.8329
# Checking accuracy on validation set
# Got 740 / 1000 correct (74.00)
#
# Iteration 0, loss = 0.6364
# Checking accuracy on validation set
# Got 726 / 1000 correct (72.60)
#
# Iteration 100, loss = 0.6852
# Checking accuracy on validation set
# Got 751 / 1000 correct (75.10)
#
# Iteration 200, loss = 0.9995
# Checking accuracy on validation set
# Got 736 / 1000 correct (73.60)
#
# Iteration 300, loss = 0.7699
# Checking accuracy on validation set
# Got 727 / 1000 correct (72.70)
#
# Iteration 400, loss = 0.6680
# Checking accuracy on validation set
# Got 734 / 1000 correct (73.40)
#
# Iteration 500, loss = 0.8296
# Checking accuracy on validation set
# Got 737 / 1000 correct (73.70)
#
# Iteration 600, loss = 0.7434
# Checking accuracy on validation set
# Got 732 / 1000 correct (73.20)
#
# Iteration 700, loss = 0.7832
# Checking accuracy on validation set
# Got 685 / 1000 correct (68.50)
#
# Iteration 0, loss = 0.5732
# Checking accuracy on validation set
# Got 723 / 1000 correct (72.30)
#
# Iteration 100, loss = 0.5669
# Checking accuracy on validation set
# Got 748 / 1000 correct (74.80)
#
# Iteration 200, loss = 0.4953
# Checking accuracy on validation set
# Got 719 / 1000 correct (71.90)
#
# Iteration 300, loss = 0.6100
# Checking accuracy on validation set
# Got 712 / 1000 correct (71.20)
#
# Iteration 400, loss = 0.8910
# Checking accuracy on validation set
# Got 731 / 1000 correct (73.10)
#
# Iteration 500, loss = 0.7715
# Checking accuracy on validation set
# Got 713 / 1000 correct (71.30)
#
# Iteration 600, loss = 0.7751
# Checking accuracy on validation set
# Got 763 / 1000 correct (76.30)
#
# Iteration 700, loss = 0.6236
# Checking accuracy on validation set
# Got 736 / 1000 correct (73.60)
# 0.736

# %% [markdown]
# Final results on the test set

# %%
acc_final_model1 = check_accuracy_part34(loader_test, model1)
# Out:
# Checking accuracy on test set
# Got 7070 / 10000 correct (70.70)

# %%
acc_final_model2 = check_accuracy_part34(loader_test, model2)
# Out:
# Checking accuracy on test set
# Got 7253 / 10000 correct (72.53)

# %%
acc_final_model3 = check_accuracy_part34(loader_test, model3)
# Out:
# Checking accuracy on test set
# Got 7327 / 10000 correct (73.27)

# %%
acc_final_model4 = check_accuracy_part34(loader_test, model4)
# Out:
# Checking accuracy on test set
# Got 6798 / 10000 correct (67.98)

# %%
acc_final_model5 = check_accuracy_part34(loader_test, model5)
# Out:
# Checking accuracy on test set
# Got 7302 / 10000 correct (73.02)

# %% [markdown]
# For this particular architecture, the adagrad optimizer performs the best on the test data.
